# %% [markdown]
# # Mi primer Hola Mundo en Notebooks

# %%
print("Hola Mundo")
# Out:
# Hola Mundo

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [2, 3, 5, 7, 11]

plt.plot(x, y)
plt.show()

# %% [markdown]
# # Pogramando de forma tradicional (antes de ML)

# %%
print("=== Sistema de aprobación ===")

edad = int(input("Ingrese su edad: "))

if edad > 18:
    trabajo = input("¿Tiene trabajo? (si/no): ").lower()

    if trabajo == "si":
        print("Resultado: APROBADO")
    else:
        print("Resultado: RECHAZADO")
else:
    print("Resultado: RECHAZADO")
# Out:
# === Sistema de aprobación ===
# Resultado: APROBADO

# %% [markdown]
# # Un grafico de regresion

# %%
import matplotlib.pyplot as plt
import numpy as np

# Datos de ejemplo
horas_estudio = np.array([2, 4, 6, 8])
nota = np.array([3, 3, 8, 9])

# Calcular la recta de regresión
coeficientes = np.polyfit(horas_estudio, nota, 1)
pendiente, intercepto = coeficientes

# Generar puntos para la recta
x_recta = np.linspace(1, 9, 100)
y_recta = pendiente * x_recta + intercepto

# Gráfico
plt.figure(figsize=(8, 5))

# Puntos de alumnos
plt.scatter(
    horas_estudio,
    nota,
    color="blue",
    s=100,
    label="Alumnos"
)

# Etiquetas de cada punto
for i in range(len(horas_estudio)):
    plt.annotate(
        f"Alumno {i+1}",
        (horas_estudio[i], nota[i]),
        xytext=(5, 5),
        textcoords="offset points"
    )

# Recta de regresión
plt.plot(
    x_recta,
    y_recta,
    color="red",
    linewidth=2,
    label="Regresión lineal"
)

plt.title("Horas de estudio vs Nota obtenida")
plt.xlabel("Horas de estudio")
plt.ylabel("Nota")
plt.xlim(0, 10)
plt.ylim(0, 10)
plt.grid(True, alpha=0.3)
plt.legend()

plt.show()

# %% [markdown]
# # Un hola mundo en ML

# %%
from sklearn.linear_model import LinearRegression

X = [ 
        [1], 
        [2], 
        [3], 
        [4], 
        [5] 
    ]
y = [ 2, 4, 6, 8 , 10 ]

model = LinearRegression()

model.fit(X, y)
# Out:
# LinearRegression()

# %%
prediccion = model.predict([[10]])

print(f"La predicción para 10 es: {prediccion[0]}")
# Out:
# La predicción para 10 es: 20.0

# %% [markdown]
# # Otro ejemplo

# %%
from sklearn.linear_model import LinearRegression

X = [ 
        [0.8], 
        [2.2], 
        [2.9], 
        [4.1], 
        [5.2] 
    ]
y = [ 2, 4, 6, 8 , 10 ]

model = LinearRegression()

model.fit(X, y)
# Out:
# LinearRegression()

# %%
prediccion = model.predict([[10]])

print(f"La predicción para 10 es: {prediccion[0]}")
# Out:
# La predicción para 10 es: 18.915712799167526

# %% [markdown]
# # Ahora con mas de un feature (2 features)

# %%
X = [ 
        [1, 1], 
        [2, 3], 
        [3, 3], 
        [4, 2], 
        [5, 1] 
    ]
y = [ 1, 6, 9, 8 , 5 ]

model = LinearRegression()

model.fit(X, y)
# Out:
# LinearRegression()

# %%
# Forzar un error a propisto y de paso leer el error de la consola para ver que pasa
prediccion = model.predict([[10]])

print(f"La predicción para 10 es: {prediccion[0]}")

# ValueError: X has 1 features, but LinearRegression is expecting 2 features as input.
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 prediccion = model.predict([[10]])
#       3 print(f"La predicción para 10 es: {prediccion[0]}")
#
# File c:\Coding\Python\Lib\site-packages\sklearn\linear_model\_base.py:311, in LinearModel.predict(self, X)
#     297 def predict(self, X):
#     298     """
#     299     Predict using the linear model.
#     300
#    (...)
#     309         Returns predicted values.
#     310     """
# --> 311     return self._decision_function(X)
#
# File c:\Coding\Python\Lib\site-packages\sklearn\linear_model\_base.py:290, in LinearModel._decision_function(self, X)
#     287 def _decision_function(self, X):
#     288     check_is_fitted(self)
# --> 290     X = validate_data(self, X, accept_sparse=["csr", "csc", "coo"], reset=False)
#     291     coef_ = self.coef_
#     292     if coef_.ndim == 1:
#
# File c:\Coding\Python\Lib\site-packages\sklearn\utils\validation.py:2923, in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    2920     out = X, y
#    2922 if not no_val_X and check_params.get("ensure_2d", True):
# -> 2923     _check_n_features(_estimator, X, reset=reset)
#    2925 return out
#
# File c:\Coding\Python\Lib\site-packages\sklearn\utils\validation.py:2787, in _check_n_features(estimator, X, reset)
#    2784     return
#    2786 if n_features != estimator.n_features_in_:
# -> 2787     raise ValueError(
#    2788         f"X has {n_features} features, but {estimator.__class__.__name__} "
#    2789         f"is expecting {estimator.n_features_in_} features as input."
#    2790     )
#
# ValueError: X has 1 features, but LinearRegression is expecting 2 features as input.

# %%
prediccion = model.predict([ [2,4] ])

print(f"La predicción para [2,4] es: {prediccion[0]}")
# Out:
# La predicción para [2,4] es: 9.67179487179487

# %%
varias_predicciones = model.predict([ [2,4], [3,5], [1,1] ])

print(f"Las predicciones para [[2,4], [3,5], [1,1]] son: {varias_predicciones}")
# Out:
# Las predicciones para [[2,4], [3,5], [1,1]] son: [ 9.67179487 13.49230769  0.72307692]

# %% [markdown]
# # Vamos a hacer una regresion lineal y un dibujo

# %%
from sklearn.linear_model import LinearRegression

X = [ 
        [0.7], 
        [2.5], 
        [2.7], 
        [4.3], 
        [5.5] 
    ]
y = [ 2, 4, 6, 8 , 10 ]

model = LinearRegression()

model.fit(X, y)
# Out:
# LinearRegression()

# %%
import matplotlib.pyplot as plt

plt.scatter(X, y, color='blue', label='Datos de entrenamiento')

plt.xlabel('Feature X')
plt.ylabel('Label y')
plt.title("Regresion Lineal")
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

y_pred = model.predict(X)

plt.scatter(X, y, color='blue', label='Datos de entrenamiento')
plt.plot(X, y_pred, color='red', label='Predicción del modelo')

plt.xlabel('Feature X')
plt.ylabel('Label y')
plt.title("Regresion Lineal")
plt.legend()
plt.show()
